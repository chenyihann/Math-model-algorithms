# %% [markdown]
# # pandas库

# %% [markdown]
# pandas库简单操作excel里的数据

# %%
# 文件读入保存,但是会覆盖原数据
import pandas as pd

data = pd.read_excel(r"C:\Users\huawei\Desktop\附件一：多源机会信号建模与导航分析问题.xlsx", sheet_name=1)

# 增加新一列deta_t
data['deta_t'] = data['TOA1'] - data['TOA4']

# 将数据转化为numpy的处理对象(解方程)
t1 = data1['TOA1'].to_numpy()

# sheet_name='...'只能是字符串，to_excel会覆盖原有的数据
data['deta_t'].to_excel(r"C:\Users\huawei\Desktop\新建 Microsoft Excel 工作表.xlsx", index=None, sheet_name='sheet1')

print(data['deta_t'][0:21])

# %% [markdown]
# 对excel里的数据进行增删改查

# %%
import pandas as pd

# 创建数据框
data = {'Name': ['Tom', 'Jerry', 'Mickey', 'Donald'],
        'Age': [20, 25, 22, 28],
        'Gender': ['M', 'M', 'M', 'M']}
df = pd.DataFrame(data)

# 删除一行数据
df = df.drop(0)  # 删除第一行数据
print(df)

# 删除一列数据
df = df.drop('Gender', axis=1)  # 删除“Gender”列
print(df)

# 添加一行新数据
new_data = {'Name': 'Daisy', 'Age': 24, 'Gender': 'F'}
df = df.append(new_data, ignore_index=True)  # 添加一行新数据
print(df)

# 添加一列新数据
new_column = ['A', 'B', 'C', 'D']
df['NewColumn'] = new_column  # 添加一列新数据
print(df)

# %% [markdown]
# 写入新的excel里的多张表

# %%
import pandas as pd

# 假定你已经有两个DF数据块：df1和df2
#读取.xlsx文件
writer = pd.ExcelWriter('test_new.xlsx')
df1.to_excel(writer, sheet_name='sheet1')
df2.to_excel(writer, sheet_name='sheet2')
writer.save()

# %% [markdown]
# 往已有的文件里添加新的表，需要导入openpyxl模块

# %%
import pandas as pd
from openpyxl import *

# 假定你已经有一个新的DF数据块：df

writer = pd.ExcelWriter('test_exist.xlsx', engin='openpyxl')
book = load_workbook(writer.path)
writer.book = book
df.to_excel(excel_writer=writer, sheet_name='sheet3')
writer.save()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# 1. 读取Excel数据

# 第一行数据非列标签
df = pd.read_excel(r"C:\Users\huawei\Desktop\11.xlsx",header = None)

# 2. 提取X, Y, Z 数据
x = df.iloc[0, 1:].values  # 第一行，从第二列开始为X坐标
y = df.iloc[1:, 0].values  # 第一列，从第二行开始为Y坐标
z = df.iloc[1:, 1:].values # 矩形区域为Z值

# 3. 创建一个3D图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 4. 创建网格，适用于曲面图或3D散点图
X, Y = np.meshgrid(x, y)

# 5. 绘制3D曲面图
ax.plot_surface(X, Y, z, cmap='viridis')

# 6. 设置坐标轴标签
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# 7. 显示图形
plt.show()
